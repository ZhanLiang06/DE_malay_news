# %%
# Available Topics correspond to the ploting function:
# ("lemma_length_analysis",plot_lemma_length)
# ("word_length_analysis",plot_word_length)
# ("lexicon_analysis", plot_lexicon_analysis)
# ("sentiment_dist_analysis",plot_sentiment_dist)
# ("word_freq_with_stopwords",plot_word_freq_with_stopwords)
# ("word_freq_without_stopwords",plot_word_freq_without_stopwords)
# ("POSDistribution",plot_POS_distribution)
# ("morphological_analysis",plot_morphological)
import sys
import os

sys.path.append(os.path.dirname(os.path.abspath("DE_malay_news")) + "/..")
from lexicraft import AnalysisVisualization
# Out:
# /home/student/de-prj/de-venv/lib/python3.10/site-packages/malaya/tokenizer.py:214: FutureWarning: Possible nested set at position 3397
#   self.tok = re.compile(r'({})'.format('|'.join(pipeline)))
# /home/student/de-prj/de-venv/lib/python3.10/site-packages/malaya/tokenizer.py:214: FutureWarning: Possible nested set at position 3927
#   self.tok = re.compile(r'({})'.format('|'.join(pipeline)))

# %% [markdown]
# ## Use Spark Structure Streaming to receive analysis result

# %%
AnalysisVisualization.visualize_analysis_topic_spark_streaming("lemma_length_analysis", AnalysisVisualization.plot_lemma_length, 'localhost:9092', 0)
# Out:
# Last Analysis Result Received Time:  2024-12-22 12:46:14

# %%
AnalysisVisualization.visualize_analysis_topic_spark_streaming("word_length_analysis", AnalysisVisualization.plot_word_length, 'localhost:9092', 0)
# Out:
# Last Analysis Result Received Time:  2024-12-22 12:46:14

# %%
AnalysisVisualization.visualize_analysis_topic_spark_streaming("lexicon_analysis", AnalysisVisualization.plot_lexicon_analysis, 'localhost:9092', 0)
# Out:
# /home/student/DE_malay_news/Notebooks/../lexicraft/visualize_analysis.py:203: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=labels, y=values, palette='viridis')
# Last Analysis Result Received Time:  2024-12-22 12:46:28

# %%
AnalysisVisualization.visualize_analysis_topic_spark_streaming("sentiment_dist_analysis", AnalysisVisualization.plot_sentiment_dist, 'localhost:9092', 0)
# Out:
# /home/student/DE_malay_news/Notebooks/../lexicraft/visualize_analysis.py:238: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=pos, y=counts, palette="coolwarm")
# Last Analysis Result Received Time:  2024-12-22 12:46:27

# %%
AnalysisVisualization.visualize_analysis_topic_spark_streaming("word_freq_with_stopwords", AnalysisVisualization.plot_word_freq_with_stopwords, 'localhost:9092', 0)
# Out:
# /home/student/DE_malay_news/Notebooks/../lexicraft/visualize_analysis.py:252: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=words, y=counts, palette="viridis")
# Last Analysis Result Received Time:  2024-12-22 12:46:27

# %%
AnalysisVisualization.visualize_analysis_topic_spark_streaming("word_freq_without_stopwords", AnalysisVisualization.plot_word_freq_without_stopwords, 'localhost:9092', 0)
# Out:
# /home/student/DE_malay_news/Notebooks/../lexicraft/visualize_analysis.py:270: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=words, y=counts, palette="viridis")
# Last Analysis Result Received Time:  2024-12-22 12:46:28

# %%
AnalysisVisualization.visualize_analysis_topic_spark_streaming("POSDistribution", AnalysisVisualization.plot_POS_distribution, 'localhost:9092', 0)
# Out:
# Last Analysis Result Received Time:  2024-12-22 12:46:27

# %%
AnalysisVisualization.visualize_analysis_topic_spark_streaming("morphological_analysis", AnalysisVisualization.plot_morphological, 'localhost:9092', 0)
# Out:
# /home/student/DE_malay_news/Notebooks/../lexicraft/visualize_analysis.py:340: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=prefix_counts.index, y=prefix_counts.values, palette="viridis")
# /home/student/DE_malay_news/Notebooks/../lexicraft/visualize_analysis.py:355: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=suffix_counts.index, y=suffix_counts.values, palette="magma")
# Last Analysis Result Received Time:  2024-12-22 12:46:26

# %% [markdown]
# ## Use Kafka Consumer To Receive Result

# %%
AnalysisVisualization.visualize_analysis_topic_kafka("lemma_length_analysis", AnalysisVisualization.plot_lemma_length, False, 'localhost:9092', 0)
# Out:
# Last Analysis Result Received Time:  2024-12-22 12:46:14

# %%
AnalysisVisualization.visualize_analysis_topic_kafka("word_length_analysis", AnalysisVisualization.plot_word_length, False, 'localhost:9092', 0)
# Out:
# Last Analysis Result Received Time:  2024-12-22 12:46:14

# %%
AnalysisVisualization.visualize_analysis_topic_kafka("lexicon_analysis", AnalysisVisualization.plot_lexicon_analysis, False, 'localhost:9092', 0)
# Out:
# /home/student/DE_malay_news/Notebooks/../lexicraft/visualize_analysis.py:203: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=labels, y=values, palette='viridis')
# Last Analysis Result Received Time:  2024-12-22 12:46:28

# %%
AnalysisVisualization.visualize_analysis_topic_kafka("sentiment_dist_analysis", AnalysisVisualization.plot_sentiment_dist, False, 'localhost:9092', 0)
# Out:
# /home/student/DE_malay_news/Notebooks/../lexicraft/visualize_analysis.py:238: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=pos, y=counts, palette="coolwarm")
# Last Analysis Result Received Time:  2024-12-22 12:46:27

# %%
AnalysisVisualization.visualize_analysis_topic_kafka("word_freq_with_stopwords", AnalysisVisualization.plot_word_freq_with_stopwords, False, 'localhost:9092', 0)
# Out:
# /home/student/DE_malay_news/Notebooks/../lexicraft/visualize_analysis.py:252: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=words, y=counts, palette="viridis")
# Last Analysis Result Received Time:  2024-12-22 12:46:27

# %%
AnalysisVisualization.visualize_analysis_topic_kafka("word_freq_without_stopwords", AnalysisVisualization.plot_word_freq_without_stopwords, False, 'localhost:9092', 0)
# Out:
# /home/student/DE_malay_news/Notebooks/../lexicraft/visualize_analysis.py:270: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=words, y=counts, palette="viridis")
# Last Analysis Result Received Time:  2024-12-22 12:46:28

# %%
AnalysisVisualization.visualize_analysis_topic_kafka("POSDistribution", AnalysisVisualization.plot_POS_distribution, False, 'localhost:9092', 0)
# Out:
# Last Analysis Result Received Time:  2024-12-22 12:46:27

# %%
AnalysisVisualization.visualize_analysis_topic_kafka("morphological_analysis", AnalysisVisualization.plot_morphological, False, 'localhost:9092', 0)
# Out:
# /home/student/DE_malay_news/Notebooks/../lexicraft/visualize_analysis.py:340: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=prefix_counts.index, y=prefix_counts.values, palette="viridis")
# /home/student/DE_malay_news/Notebooks/../lexicraft/visualize_analysis.py:355: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=suffix_counts.index, y=suffix_counts.values, palette="magma")
# Last Analysis Result Received Time:  2024-12-22 12:46:26

# %% [markdown]
# #### Get Raw Result Data From Kafka

# %%
message = AnalysisVisualization.get_kafka_topic_latest_message("lemma_length_analysis",'localhost:9092', 0)
print(message.value)
# Out:
# {'word_lengths': [6, 5, 4, 4, 4, 3, 6, 6, 5, 5, 6, 5, 7, 4, 5, 4, 4, 5, 8, 5, 5, 6, 5, 8, 5, 6, 7, 4, 5, 7, 4, 7, 8, 3, 4, 6, 5, 2, 4, 5, 5, 5, 4, 6, 5, 9, 4, 7, 8, 6, 5, 3, 7, 7, 6, 6, 4, 5, 5, 5, 5, 7, 5, 4, 5, 5, 6, 8, 5, 5, 12, 6, 5, 5, 5, 4, 6, 4, 5, 3, 10, 12, 6, 5, 5, 4, 8, 5, 5, 5, 6, 6, 4, 7, 5, 2, 13, 4, 11, 7, 10, 6, 5, 6, 3, 7, 4, 4, 4, 7, 6, 5, 4, 4, 5, 6, 5, 7, 12, 4, 5, 7, 4, 4, 6, 4, 8, 4, 5, 5, 4, 5, 5, 7, 3, 4, 7, 7, 5, 6, 6, 5, 3, 5, 7, 9, 7, 5, 5, 7, 6, 4, 4, 7, 6, 4, 6, 5, 6, 4, 4, 5, 7, 4, 9, 5, 5, 5, 6, 5, 6, 8, 5, 5, 5, 5, 6, 5, 5, 5, 6, 6, 3, 5, 12, 3, 8, 4, 4, 4, 6, 5, 7, 4, 8, 5, 3, 4, 7, 7, 4, 7, 7, 4, 5, 6, 6, 5, 5, 5, 6, 5, 5, 6, 7, 11, 7, 4, 11, 7, 5, 6, 7, 7, 8, 6, 5, 9, 3, 6, 5, 5, 5, 6, 5, 6, 5, 6, 11, 6, 5, 4, 5, 5, 6, 5, 5, 5, 6, 4, 11, 7, 5, 5, 5, 7, 2, 6, 5, 4, 5, 5, 7, 5, 2, 12, 4, 3, 7, 4, 6, 4, 7, 5, 5, 9, 6, 6, 6, 6, 13, 10, 6, 8, 6, 3, 4, 6, 5, 4, 5, 4, 6, 7, 5, 5, 4, 10, 6, 4, 5, 4, 5, 7, 9, 6, 6, 6, 6, 5, 7, 5, 6, 11, 9, 9, 9, 9, 5, 10, 6, 7, 5, 5, 7, 4, 10, 4, 7, 6, 7, 5, 6, 5, 5, 3, 6, 14, 7, 9, 4, 5, 6, 7, 5, 8, 4, 5, 
# %%
message = AnalysisVisualization.get_kafka_topic_latest_message("lexicon_analysis",'localhost:9092', 0)
print(message.value)
# Out:
# [{'totalWords': 2375, 'totalPeri': 180}]

# %%
message = AnalysisVisualization.get_kafka_topic_latest_message("sentiment_dist_analysis",'localhost:9092', 0)
print(message.value)
# Out:
# [{'label': 'neutral', 'total_count': 1371}, {'label': 'negative', 'total_count': 510}, {'label': 'positive', 'total_count': 494}]

# %%
message = AnalysisVisualization.get_kafka_topic_latest_message("word_freq_with_stopwords",'localhost:9092', 0)
print(message.value)
# Out:
# [{'word': 'yang', 'count': 64}, {'word': 'dengan', 'count': 25}, {'word': 'ini', 'count': 25}, {'word': 'dalam', 'count': 23}, {'word': 'pada', 'count': 21}, {'word': 'untuk', 'count': 21}, {'word': 'berkata', 'count': 17}, {'word': 'kepada', 'count': 17}, {'word': 'india', 'count': 16}, {'word': 'rm', 'count': 16}, {'word': 'um', 'count': 15}, {'word': 'universiti', 'count': 13}, {'word': 'perlu', 'count': 12}, {'word': 'bagi', 'count': 12}, {'word': 'saya', 'count': 12}]

# %%
message = AnalysisVisualization.get_kafka_topic_latest_message("word_freq_without_stopwords",'localhost:9092', 0)
print(message.value)
# Out:
# [{'word': 'rm', 'count': 16}, {'word': 'um', 'count': 15}, {'word': 'universiti', 'count': 13}, {'word': 'kucing', 'count': 12}, {'word': 'siasatan', 'count': 11}, {'word': 'kampung', 'count': 11}, {'word': 'banjir', 'count': 10}, {'word': 'hutang', 'count': 10}, {'word': 'bantuan', 'count': 10}, {'word': 'komuniti', 'count': 10}, {'word': 'kejadian', 'count': 10}, {'word': 'segera', 'count': 9}, {'word': 'kesan', 'count': 8}, {'word': 'mangsa', 'count': 8}, {'word': 'usahawan', 'count': 8}]

# %%
message = AnalysisVisualization.get_kafka_topic_latest_message("POSDistribution",'localhost:9092', 0)
print(message.value)
# Out:
# [{'pos': 'Proper noun', 'total_count': 2302}, {'pos': 'Noun', 'total_count': 63}, {'pos': 'Adposition', 'total_count': 9}, {'pos': 'Number', 'total_count': 1}]

# %%
message = AnalysisVisualization.get_kafka_topic_latest_message("morphological_analysis",'localhost:9092', 0)
print(message.value)
# Out:
# [{"word":"berkata","stem":"kata","prefix":"ber","suffix":"","core_word":"kata"},{"word":"canselor","stem":"canselor","prefix":null,"suffix":null,"core_word":"canselor"},{"word":"berkuasa","stem":"kuasa","prefix":"ber","suffix":"","core_word":"kuasa"},{"word":"dakwaan","stem":"dakwa","prefix":"","suffix":"an","core_word":"dakwa"},{"word":"dengan","stem":"dengan","prefix":null,"suffix":null,"core_word":"dengan"},{"word":"dakwa","stem":"dakwa","prefix":null,"suffix":null,"core_word":"dakwa"},{"word":"kuasa","stem":"kuasa","prefix":null,"suffix":null,"core_word":"kuasa"},{"word":"mandat","stem":"mandat","prefix":null,"suffix":null,"core_word":"mandat"},{"word":"dalam","stem":"dalam","prefix":null,"suffix":null,"core_word":"dalam"},{"word":"minat","stem":"minat","prefix":null,"suffix":null,"core_word":"minat"},{"word":"imej","stem":"imej","prefix":null,"suffix":null,"core_word":"imej"},{"word":"terus","stem":"terus","prefix":null,"suffix":null,"core_word":"terus"},{"word":"laporan","stem":"lapor","prefix":"","suffix":"an","core_word":"lapor"},{"word":"terpaksa","stem":"paksa","prefix":"ter","suffix":"","core_word":"paksa"},{"word":"lapor","stem":"lapor","prefix":null,"suffix":null,"core_word":"lapor"},{"word":"perlu","stem":"perlu","prefix":null,"suffix":null,"core_word":"perlu"},{"word":"bayang-bayang","stem":"bayang","prefix":"","suffix":"-bayang","core_word":"bayang"},{"word":"lima","stem":"lima","prefix":null,"suffix":null,"core_word":"lima"},{"word":"harus","stem":"harus","prefix":null,"suffix":null,"core_word":"harus"},{"word":"menggambarkan","stem":"gambar","prefix":"meng","suffix":"kan","core_word":"gambar"},{"word":"terurai","stem":"urai","prefix":"ter","suffix":"","core_word":"urai"},{"word":"bekas","stem":"bekas","prefix":null,"suffix":null,"core_word":"bekas"},{"word":"alif","stem":"alif","prefix":null,"suffix":null,"core_word":"alif"},{"word":"surih","stem":"surih","prefix":null,"suffix":null,"core_word":"surih"},{"word":"saudara","stem":"saudara","prefix":null,"suffix":null,"core_word":"saudara"},{"word":"rakan","stem":"rakan","prefix":null,"suffix":null,"core_word":"rakan"},{"word":"tapak","stem":"tapak","prefix":null,"suffix":null,"core_word":"tapak"},{"word":"tanda","stem":"tanda","prefix":null,"suffix":null,"core_word":"tanda"},{"word":"menyeluruh","stem":"seluruh","prefix":null,"suffix":null,"core_word":"seluruh"},{"word":"kalimah","stem":"kalimah","prefix":null,"suffix":null,"core_word":"kalimah"},{"word":"melaksanakan","stem":"laksana","prefix":"me","suffix":"kan","core_word":"laksana"},{"word":"ringan","stem":"ringan","prefix":null,"suffix":null,"core_word":"ringan"},{"word":"melemahkan","stem":"lemah","prefix":"me","suffix":"kan","core_word":"lemah"},{"word":"pencinta","stem":"cinta","prefix":"pen","suffix":"","core_word":"cinta"},{"word":"gampang","stem":"gampang","prefix":null,"suffix":null,"core_word":"gampang"},{"word":"sidi","stem":"sidi","prefix":null,"suffix":null,"core_word":"sidi"},{"word":"ukuran","stem":"ukur","prefix":"","suffix":"an","core_word":"ukur"},{"word":"pentan","stem":"pentan","prefix":null,"suffix":null,"core_word":"pentan"},{"word":"remeh","stem":"remeh","prefix":null,"suffix":null,"core_word":"remeh"},{"word":"longlai","stem":"longlai","prefix":null,"suffix":null,"core_word":"longlai"},{"word":"ejen","stem":"ejen","prefix":null,"suffix":null,"core_word":"ejen"},{"word":"sidang","stem":"sidang","prefix":null,"suffix":null,"core_word":"sidang"},{"word":"telah","stem":"telah","prefix":null,"suffix":null,"core_word":"telah"},{"word":"teliti","stem":"teliti","prefix":null,"suffix":null,"core_word":"teliti"},{"word":"wan","stem":"wan","prefix":null,"suffix":null,"core_word":"wan"},{"word":"wilayah","stem":"wilayah","prefix":null,"suffix":null,"core_word":"wilayah"},{"word":"singkat","stem":"singkat","prefix":null,"suffix":null,"core_word":"singkat"},{"word":"biasa","stem":"biasa","prefix":null,"suffix":null,"core_word":"biasa"},{"word":"berlebih","stem":"lebih","prefix":"ber","suffix":"","c ...
